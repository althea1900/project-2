# %%
# Dependencies
import requests
import json
import pandas as pd
# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "37.54, -77.45"
target_radius = 10000
target_type = "hospital"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHQEAAJpoKnK5micYQ96c4xJWilWGjS_k3jdRwZDZ8kt7F0kP4vBEPRfGWU7flyHQqXJwmYIbxigoTsIb-s0Y4k49kYh4C_BnWvR2Ne9EfkxM_17zc5gTJK3s2FK7XHWLfa8ngfvWan2-sqR149OHQQQcMkAyy_6I9iz1fW2TTNnX493cGPbtZ_ivO2jkXfq2LefwEJtZ2Aa1cllHSjQ6cbH6fhFWmhUc1TktqU5c_B-uByY2FJn9nUeHItujXh0D75HJlntj81CGbBCLGzChZ0Ym76ayRmwwbT9iaCczQeWZUL8MYY611rMfRLbqLwotGoYWmANcBZqChFU5tapVBLjXJZvHqabasa-0M-iBArPZorhDPdNqK4bEikJvoByff4yDqxIQwYBvELcH1QtN7wuSimPiWBoUC87oo6cEXG8hwS5YYBFKlBO3rQg",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5138861,
#                     "lng": -77.5263523
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5156581802915,
#                         "lng": -77.52521566970849
#                     },
#                     "southwest": {
#                         "lat": 37.5129602197085,
#                         "lng": -77.52791363029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Chippenham Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 499,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100860276573522276168\">Chippenham Hospital</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9jlb22Q1RTX8xi55Kijg-0onwlfrWiKfEvH7Gpeilx1M2T3UyVCJpJx_Tz63PCpgMekwyMZEd5dtlwAUoXalJIi-hOv3IHDGVTij8aCk1WYTDzMxr-PnYGH3yrDAck_YEhBga58rgqeqomzyUBBd1GjuGhROHKRhbWsYw5nIoJAII4a3FKr4gw",
#                     "width": 888
#                 }
#             ],
#             "place_id": "ChIJl2uycvASsYkR7R-ObjcZEmo",
#             "plus_code": {
#                 "compound_code": "GF7F+HF Richmond, VA, USA",
#                 "global_code": "8794GF7F+HF"
#             },
#             "rating": 3.9,
#             "reference": "ChIJl2uycvASsYkR7R-ObjcZEmo",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "doctor",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 797,
#             "vicinity": "7101 Jahnke Road, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5836196,
#                     "lng": -77.5123101
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5878126,
#                         "lng": -77.50849640000001
#                     },
#                     "southwest": {
#                         "lat": 37.58055540000001,
#                         "lng": -77.51795520000002
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Bon Secours St. Mary's Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117226902714500411389\">ayman ghaly</a>"
#                     ],
#                     "photo_reference": "CmRaAAAANlJ2OBSSaiuofdv6g55RborXXlcEclqfRTEDacwqXQ67x-3T1qR3KqbcOkxHem-j0xLnUP3AtrDdXQdNqSoDxKosiILJ8VAYLz1oNEtDZB7BPdKV-umYXyRxz5UdosIWEhAa5I6XCkUNDE27xFysq76kGhRLQ95gOwTvyg_0HSShZVsAIKZneg",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJBUGmEmEUsYkR_YBA-2gsf9g",
#             "plus_code": {
#                 "compound_code": "HFMQ+C3 Richmond, VA, USA",
#                 "global_code": "8794HFMQ+C3"
#             },
#             "rating": 3.4,
#             "reference": "ChIJBUGmEmEUsYkR_YBA-2gsf9g",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 322,
#             "vicinity": "5801 Bremo Road, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.540184,
#                     "lng": -77.4295959
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5415708302915,
#                         "lng": -77.42819176970849
#                     },
#                     "southwest": {
#                         "lat": 37.53887286970851,
#                         "lng": -77.43088973029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "name": "VCU Medical Center Pediatric ICU",
#             "place_id": "ChIJw1u10yMRsYkRm6wLGlLDfrk",
#             "plus_code": {
#                 "compound_code": "GHRC+35 Richmond, VA, USA",
#                 "global_code": "8794GHRC+35"
#             },
#             "rating": 3.5,
#             "reference": "ChIJw1u10yMRsYkRm6wLGlLDfrk",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "1250 East Marshall Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.51568299999999,
#                     "lng": -77.526097
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5170122802915,
#                         "lng": -77.5247376197085
#                     },
#                     "southwest": {
#                         "lat": 37.5143143197085,
#                         "lng": -77.52743558029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Ms. Cynthia Schieck",
#             "place_id": "ChIJl2uycvASsYkRLSHn5G5drcw",
#             "plus_code": {
#                 "compound_code": "GF8F+7H Richmond, VA, USA",
#                 "global_code": "8794GF8F+7H"
#             },
#             "reference": "ChIJl2uycvASsYkRLSHn5G5drcw",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "7101 Jahnke Road, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.57091509999999,
#                     "lng": -77.4510006
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5724429302915,
#                         "lng": -77.4497694197085
#                     },
#                     "southwest": {
#                         "lat": 37.5697449697085,
#                         "lng": -77.45246738029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "VCU Center for Craniofacial Care",
#             "place_id": "ChIJVYFNY7cWsYkRl7cwgNpTXT4",
#             "plus_code": {
#                 "compound_code": "HGCX+9H Richmond, VA, USA",
#                 "global_code": "8794HGCX+9H"
#             },
#             "reference": "ChIJVYFNY7cWsYkRl7cwgNpTXT4",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2924 Brook Road, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5675608,
#                     "lng": -77.4792556
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5688523802915,
#                         "lng": -77.4777706697085
#                     },
#                     "southwest": {
#                         "lat": 37.5661544197085,
#                         "lng": -77.48046863029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Health Brigade",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJ32NjXQYUsYkRGVbSp51wp6w",
#             "plus_code": {
#                 "compound_code": "HG9C+27 Richmond, VA, USA",
#                 "global_code": "8794HG9C+27"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ32NjXQYUsYkRGVbSp51wp6w",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "1010 North Thompson Street # 200, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5835123,
#                     "lng": -77.5133841
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5846704802915,
#                         "lng": -77.51191691970848
#                     },
#                     "southwest": {
#                         "lat": 37.5819725197085,
#                         "lng": -77.51461488029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "name": "Bon Secours Advanced Heart Failure Center",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJbRkl2_oUsYkRugV39o6sN88",
#             "plus_code": {
#                 "compound_code": "HFMP+CJ Richmond, VA, USA",
#                 "global_code": "8794HFMP+CJ"
#             },
#             "rating": 5,
#             "reference": "ChIJbRkl2_oUsYkRugV39o6sN88",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "doctor",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "5875 Bremo Road, MOB South Suite 400C, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5394668,
#                     "lng": -77.4303639
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5406661802915,
#                         "lng": -77.4293562697085
#                     },
#                     "southwest": {
#                         "lat": 37.5379682197085,
#                         "lng": -77.43205423029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "VCU Medical Center West Hospital",
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114826133977128493969\">James Winston</a>"
#                     ],
#                     "photo_reference": "CmRaAAAACr1fBrfpa8KX46vT26JGjvgcdaLvSy40WGDluzgeNuCmemj4FAT5NBbP13Gi97NsTOYjaTfXzR-GJ9tQeD5COu01rJl40EahxMEpbKPHf2sLiHsMQquOeUw-jYG_LWQREhDgbxieuFd03m1gFif5ezpiGhS8a59YbmztD5aPSjLPq21EgCTG3w",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJG4_FOiIRsYkRiWpKvf-SedA",
#             "plus_code": {
#                 "compound_code": "GHQ9+QV Richmond, VA, USA",
#                 "global_code": "8794GHQ9+QV"
#             },
#             "rating": 4.7,
#             "reference": "ChIJG4_FOiIRsYkRiWpKvf-SedA",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 9,
#             "vicinity": "1200 East Broad Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5404075,
#                     "lng": -77.4067922
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5415595802915,
#                         "lng": -77.4052774197085
#                     },
#                     "southwest": {
#                         "lat": 37.53886161970851,
#                         "lng": -77.4079753802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Richmond Community Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJA7Wws8YQsYkRkR7wtdymDpI",
#             "plus_code": {
#                 "compound_code": "GHRV+57 Richmond, VA, USA",
#                 "global_code": "8794GHRV+57"
#             },
#             "rating": 4.8,
#             "reference": "ChIJA7Wws8YQsYkRkR7wtdymDpI",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "1500 North 28th Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5405104,
#                     "lng": -77.440705
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.54196758029151,
#                         "lng": -77.43925231970849
#                     },
#                     "southwest": {
#                         "lat": 37.53926961970851,
#                         "lng": -77.44195028029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Richmond City Health District",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 695,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105024532441907915736\">Richmond City Health District</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyJnKZIiOq6OuvZk6SMdlopYe8trQHTBnYMFlWrGvZrNWrSyZGLM7TScPLaNRP0YcCOgp444eKBfwpCrHrhJqH_EnvAv3A8Sh2sT9H7h6fT5zDOvXFFJ5kN9xXMPQA3hLEhDSAXStLlAZoHpZ0_Cb77tQGhQKS6WJtKh8XtG9TheR3k7rIre_1A",
#                     "width": 1185
#                 }
#             ],
#             "place_id": "ChIJdS162z0RsYkRB5IEsApi644",
#             "plus_code": {
#                 "compound_code": "GHR5+6P Richmond, VA, USA",
#                 "global_code": "8794GHR5+6P"
#             },
#             "rating": 3.6,
#             "reference": "ChIJdS162z0RsYkRB5IEsApi644",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 28,
#             "vicinity": "400 East Cary Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5537882,
#                     "lng": -77.4728112
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5549796302915,
#                         "lng": -77.4712583197085
#                     },
#                     "southwest": {
#                         "lat": 37.5522816697085,
#                         "lng": -77.4739562802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Retreat Doctors' Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 499,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117774543084079420377\">Retreat Doctors&#39; Hospital</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAUSRcZ-qbBFF9HpAGhIrtorG1IoSS5TOKIyuacaClOthJiSo8WLaRXRezRQFAyfGShDMNXLZQe3k18QAgol6fSX9CPES09nVEvRTHzaf9oYrk2qhRMzvRM07s2YWbX4c6EhBKHMetXuYyDKuFcNYOkgrfGhTGMhT2-wHjG75loF1diJheeln3zA",
#                     "width": 888
#                 }
#             ],
#             "place_id": "ChIJu7NbIP0TsYkReU48VBcxTws",
#             "plus_code": {
#                 "compound_code": "HG3G+GV Richmond, VA, USA",
#                 "global_code": "8794HG3G+GV"
#             },
#             "rating": 4.6,
#             "reference": "ChIJu7NbIP0TsYkReU48VBcxTws",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 240,
#             "vicinity": "2621 Grove Avenue, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5906307,
#                     "lng": -77.4907046
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5921448802915,
#                         "lng": -77.4894053197085
#                     },
#                     "southwest": {
#                         "lat": 37.58944691970851,
#                         "lng": -77.4921032802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Vibra Hospital of Richmond",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1131,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111978656370105450554\">Vibra Hospital of Richmond</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAC_FZIWA4RcU3TEezwN_VRp0vA8aKivmnCQNnOF5bvlwn8jCASKuN-quPfvMOHCoC_yez8bAq31qXkj5nkroOKKcoSfSJVgPog4Sdjh9qlSzhcLGMVJo5TcHBmGIolRuQEhAHvTn9DFqZwlgpI4qnOgxJGhTzu_AL7BbSRBhK-v2vmPEFQZDWvQ",
#                     "width": 1698
#                 }
#             ],
#             "place_id": "ChIJcZrgOT8UsYkRucNslgc8SUo",
#             "plus_code": {
#                 "compound_code": "HGR5+7P Richmond, VA, USA",
#                 "global_code": "8794HGR5+7P"
#             },
#             "rating": 3.5,
#             "reference": "ChIJcZrgOT8UsYkRucNslgc8SUo",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "2220 Edward Holland Drive, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.51388600000001,
#                     "lng": -77.5263617
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5150014802915,
#                         "lng": -77.52509606970848
#                     },
#                     "southwest": {
#                         "lat": 37.5123035197085,
#                         "lng": -77.52779403029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "CJW Med Center-Chippenham Campus",
#             "place_id": "ChIJUb6R10oRsYkRzCdtRCbVfY4",
#             "plus_code": {
#                 "compound_code": "GF7F+HF Richmond, VA, USA",
#                 "global_code": "8794GF7F+HF"
#             },
#             "rating": 4.5,
#             "reference": "ChIJUb6R10oRsYkRzCdtRCbVfY4",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "7101 Jahnke Road, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.539985,
#                     "lng": -77.4386148
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5412949302915,
#                         "lng": -77.43738541970849
#                     },
#                     "southwest": {
#                         "lat": 37.5385969697085,
#                         "lng": -77.44008338029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "name": "Vcu Health System Authority",
#             "place_id": "ChIJiW7lVyIRsYkRzdZhG-r2Ljs",
#             "plus_code": {
#                 "compound_code": "GHQ6+XH Richmond, VA, USA",
#                 "global_code": "8794GHQ6+XH"
#             },
#             "reference": "ChIJiW7lVyIRsYkRzdZhG-r2Ljs",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "university",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "600 East Main Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.55786980000001,
#                     "lng": -77.4631309
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5593286802915,
#                         "lng": -77.4616772697085
#                     },
#                     "southwest": {
#                         "lat": 37.5566307197085,
#                         "lng": -77.46437523029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Central Virginia Health Network",
#             "place_id": "ChIJkQKwx1MRsYkR8hTmZnIuuCg",
#             "plus_code": {
#                 "compound_code": "HG5P+4P Richmond, VA, USA",
#                 "global_code": "8794HG5P+4P"
#             },
#             "reference": "ChIJkQKwx1MRsYkR8hTmZnIuuCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2201 West Broad Street # 202, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5213099,
#                     "lng": -77.48950719999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.52276853029149,
#                         "lng": -77.4881002197085
#                     },
#                     "southwest": {
#                         "lat": 37.52007056970849,
#                         "lng": -77.4907981802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "name": "DaVita Forest Hill Avenue Dialysis",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114109262102478142335\">DaVita Forest Hill Avenue Dialysis</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFHJKhQ9h7bCyUnfgFbj5-80pqBSq_SBKqLZyALy-w15pxB18V9esYIzPKqT_lLWCo4fJUmrk3T3jz6FFjMyUKsFIe_9rROGInNEyAzRrwhJJ-bWuaUEfXcMrb-FxhIvUEhBOUubMg6C9CcvUvP4zkPJTGhQayYFRa-TPZJMIXq7PErMvFo6moQ",
#                     "width": 1667
#                 }
#             ],
#             "place_id": "ChIJl7eDmjQSsYkRKcrON_wmABE",
#             "plus_code": {
#                 "compound_code": "GGC6+G5 Richmond, VA, USA",
#                 "global_code": "8794GGC6+G5"
#             },
#             "rating": 3,
#             "reference": "ChIJl7eDmjQSsYkRKcrON_wmABE",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "4900 Forest Hill Avenue, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5402473,
#                     "lng": -77.4069749
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5415058802915,
#                         "lng": -77.4058471697085
#                     },
#                     "southwest": {
#                         "lat": 37.5388079197085,
#                         "lng": -77.4085451302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "Bon Secours Richmond Community Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJq6qqqo4UsYkRD4FCSsrHSYU",
#             "plus_code": {
#                 "compound_code": "GHRV+36 Richmond, VA, USA",
#                 "global_code": "8794GHRV+36"
#             },
#             "rating": 3.3,
#             "reference": "ChIJq6qqqo4UsYkRD4FCSsrHSYU",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 57,
#             "vicinity": "1500 North 28th Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5407618,
#                     "lng": -77.4308166
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.54217928029151,
#                         "lng": -77.4295767697085
#                     },
#                     "southwest": {
#                         "lat": 37.53948131970851,
#                         "lng": -77.43227473029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "name": "VCU Medical Center Dermatology",
#             "place_id": "ChIJ_3Le1yMRsYkR0dpIaEembv4",
#             "plus_code": {
#                 "compound_code": "GHR9+8M Richmond, VA, USA",
#                 "global_code": "8794GHR9+8M"
#             },
#             "rating": 3,
#             "reference": "ChIJ_3Le1yMRsYkR0dpIaEembv4",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "401 North 11th Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5410315,
#                     "lng": -77.4304616
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5424720802915,
#                         "lng": -77.4292415697085
#                     },
#                     "southwest": {
#                         "lat": 37.5397741197085,
#                         "lng": -77.4319395302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "VCC Health",
#             "place_id": "ChIJIQ6qxSMRsYkRYKm1KF955ms",
#             "plus_code": {
#                 "compound_code": "GHR9+CR Richmond, VA, USA",
#                 "global_code": "8794GHR9+CR"
#             },
#             "rating": 5,
#             "reference": "ChIJIQ6qxSMRsYkRYKm1KF955ms",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "417 North 11th Street, Richmond"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 37.5405276,
#                     "lng": -77.4303934
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.5418814802915,
#                         "lng": -77.42886596970848
#                     },
#                     "southwest": {
#                         "lat": 37.5391835197085,
#                         "lng": -77.4315639302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "name": "VCU Medical Center",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3672,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117979751334919367476\">Alexander Mejia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqS8xp_jf9iW3SvbJpnfvuAE5QtMRzslxSHu_j4Tw88SXsIiQ0i-tNgnHZm5QSNhkapL5-GIlB4_6-nxx44LhWQfBEt_Zfuk8Ua9pFw0i84hnIgEkOnXtBZJW3ZAf19rdEhBbnucOJHrW1qynEoTC2AXsGhTcJGn7suHND_yJC7YleAQhZoHMuQ",
#                     "width": 4896
#                 }
#             ],
#             "place_id": "ChIJiQrK0yMRsYkRURhGodNBptQ",
#             "plus_code": {
#                 "compound_code": "GHR9+6R Richmond, VA, USA",
#                 "global_code": "8794GHR9+6R"
#             },
#             "rating": 3.1,
#             "reference": "ChIJiQrK0yMRsYkRURhGodNBptQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "1250 East Marshall Street, Richmond"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["geometry"]["location"]["lat"])
print(places_data["results"][0]["geometry"]["location"]["lng"])
print(places_data["results"][0]["name"])
# Out:
# 37.5138861
# -77.5263523
# Chippenham Hospital

# %%
len(places_data["results"])
# Out:
# 20

# %%
hospital = pd.DataFrame(columns = ["Name", "Longitude", "Latitude", "Type"])
hospital
# Out:
# Empty DataFrame
# Columns: [Name, Longitude, Latitude, Type]
# Index: []

# %%
for i in range(len(places_data["results"])):
    hospital = hospital.append({"Name": places_data["results"][i]["name"], "Longitude": places_data["results"][i]["geometry"]["location"]["lng"], "Latitude": places_data["results"][i]["geometry"]["location"]["lat"], "Type": "Hospital"}, ignore_index=True)

# %%
hospital
# Out:
#                                          Name  Longitude   Latitude      Type
# 0                         Chippenham Hospital -77.526352  37.513886  Hospital
# 1             Bon Secours St. Mary's Hospital -77.512310  37.583620  Hospital
# 2            VCU Medical Center Pediatric ICU -77.429596  37.540184  Hospital
# 3                         Ms. Cynthia Schieck -77.526097  37.515683  Hospital
# 4            VCU Center for Craniofacial Care -77.451001  37.570915  Hospital
# 5                              Health Brigade -77.479256  37.567561  Hospital
# 6   Bon Secours Advanced Heart Failure Center -77.513384  37.583512  Hospital
# 7            VCU Medical Center West Hospital -77.430364  37.539467  Hospital
# 8                 Richmond Community Hospital -77.406792  37.540408  Hospital
# 9               Richmond City Health District -77.440705  37.540510  Hospital
# 10                  Retreat Doctors' Hospital -77.472811  37.553788  Hospital
# 11                 Vibra Hospital of Richmond -77.490705  37.590631  Hospital
# 12           CJW Med Center-Chippenham Campus -77.526362  37.513886  Hospital
# 13                Vcu Health System Authority -77.438615  37.539985  Hospital
# 14            Central Virginia Health Network -77.463131  37.557870  Hospital
# 15         DaVita Forest Hill Avenue Dialysis -77.489507  37.521310  Hospital
# 16    Bon Secours Richmond Community Hospital -77.406975  37.540247  Hospital
# 17             VCU Medical Center Dermatology -77.430817  37.540762  Hospital
# 18                                 VCC Health -77.430462  37.541032  Hospital
# 19                         VCU Medical Center -77.430393  37.540528  Hospital

# %%
# geocoordinates
target_coordinates = "37.54, -77.45"
target_radius = 8000
target_type = "fire department"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
places_data = response.json()
